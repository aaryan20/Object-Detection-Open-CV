# %%
import cv2
import numpy as np
import pandas as pd
import webcolors
import json
import os

# %% [markdown]
# Tutorial I used
# https://learnopencv.com/simple-background-estimation-in-videos-using-opencv-c-python/

# %%
df = pd.DataFrame(columns=['handle_id', 'date_posted', 'instagram_link', 'content_type', 'post_description', 'number_tags', 'likes_post', 'comments_post', 'len_description', 'number_objects', 'classes_string','background_percentage', 'background_avg_color'])
df.head()
# Out:
# Empty DataFrame
# Columns: [handle_id, date_posted, instagram_link, content_type, post_description, number_tags, likes_post, comments_post, len_description, number_objects, classes_string, background_percentage, background_avg_color]
# Index: []

# %%
#  C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\kerala_tourism\keralatourism\images

# %%
##### OpenCV Model
model = cv2.dnn.readNet(model='frozen_inference_graph.pb',
                        config='ssd_mobilenet_v2_coco_2018_03_29.pbtxt',framework='TensorFlow')

# %%
# load the COCO class names
with open('object_detection_classes_coco.txt', 'r') as f:
   class_names = f.read().split('\n')
  
# get a different color array for each of the classes
COLORS = np.random.uniform(0, 255, size=(len(class_names), 3))

# %%
def json_processing(folder_path, filename):
    try:
        flag_json = 0
        executed_flag = False
        filename_json = filename[:-3]
        filename_json = filename_json + 'json'
        folder_path_json = os.path.dirname(folder_path) + "\json"
        filename_json_path = os.path.join(folder_path_json, filename_json)
        date = filename[0:10]
    
        print(filename_json)
            
        with open(filename_json_path) as f:
            data = json.load(f)
        flag_json = 1 ########################### flag working OK
        executed_flag = True
        shortcode = ((data['node']['shortcode']))
        instagram_link = 'https://www.instagram.com/keralatourism/p/' + str(shortcode) + '/'
        description = ((data['node']['edge_media_to_caption']['edges'][0]['node']['text']))
        description_len = len(description)
        number_tags = len(data['node']['edge_media_to_tagged_user']['edges'])
        likes_post = (data['node']['edge_media_preview_like']['count'])
        comments_post = (data['node']['edge_media_to_comment']['count'])
        is_video_flag = data['node']['is_video']
        content_type = ''
        if(is_video_flag == True):
            content_type = 'Video'
        else:
            content_type = 'Image'
        print('is_video_flag:', is_video_flag, type(is_video_flag))
        print(instagram_link, 'tags:', number_tags,'likes:', likes_post, 'comments:', comments_post)
        
            
            # json_columns = {'instagram_link': instagram_link, 'number_tags':number_tags, 'likes_post': likes_post, 'comments_post': comments_post}
        
        output = [date, instagram_link, content_type, description, number_tags, likes_post, comments_post, description_len] 
        # pint(instagram_link, 'tags:', number_tags,'likes:', likes_post, 'comments:', comments_post)
    

    except FileNotFoundError:
        output = []
        print("File Not Found. Please check directory.")
        return output, executed_flag
    except:
        print("Some Error Occured.")
        return output, executed_flag
    else:
        print("JSON processed successfully.")
        return output, executed_flag

# %%
def closest_colour(requested_colour):
    min_colours = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[1]) ** 2
        bd = (b_c - requested_colour[2]) ** 2
        min_colours[(rd + gd + bd)] = name
    return min_colours[min(min_colours.keys())]

# %%
## Computer Vision Function
###    Computer Vision Task 
def object_detection(file_path, model):
    flag_image = 1
    executed_flag = False
    # read the image from disk
    image = cv2.imread(file_path)
    
    image_height, image_width, _ = image.shape
    # create blob from image
    blob = cv2.dnn.blobFromImage(image=image, size=(300, 300), mean=(104, 117, 123), swapRB=True)
    # Initialize model & set the blob to the model
    model.setInput(blob)
    # load the COCO class names
    with open('object_detection_classes_coco.txt', 'r') as f:
        class_names = f.read().split('\n')
    # get a different color array for each of the classes
    COLORS = np.random.uniform(0, 255, size=(len(class_names), 3))
    
    # forward pass through the model to carry out the detection
    output = model.forward()
      
    class_names_found = []
    non_background_pixels = 0
    x1 = 0; x2 = 0; y1 = 0; y2 = 0
    # loop over each of the detection
    for detection in output[0, 0, :, :]:
        #
        # extract the confidence of the detection
        confidence = detection[2]
        # draw bounding boxes only if the detection confidence is above...
        # ... a certain threshold, else skip 
        if confidence > .4:
            # get the class id
            class_id = detection[1]
            # map the class id to the class
            class_name = class_names[int(class_id)-1]
            color = COLORS[int(class_id)]
            class_names_found.append(class_name)
            x1 = int(detection[3] * image_width)
            y1 = int(detection[4] * image_height)
            x2 = int(detection[5] * image_width)
            y2 = int(detection[6] * image_height)
            non_background_pixels += abs(x2-x1)*abs(y2-y1) 
    # Count the non-background pixels within the bounding box region
            
    total_pixels = image.shape[0] * image.shape[1]
    
    number_objects = len(class_names_found)
    classes_string = str(class_names_found)
    percentage_background = (abs(total_pixels - non_background_pixels) / total_pixels) * 100
        
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # lur the grayscale image
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    # Calculate the average background color
    average_color = np.mean(blurred)
    # Convert the average color value to integers
    average_color = int(average_color)
    # Create a blank image of the average color
    color_image = np.zeros((100, 100, 3), np.uint8)
    color_image[:] = average_color
    # Convert the average color to RGB format
    average_color_rgb = tuple(map(int, color_image[0, 0]))
    # Print the average background color in RGB
    print("Average Background Color (RGB):", average_color_rgb)
    background_avg_color = closest_colour(average_color_rgb)
    executed_flag = True
    
    output = [number_objects, classes_string, percentage_background, background_avg_color]
    return output, executed_flag

# %%
## Computer Vision Function
###    Computer Vision Task 
def object_detection(file_path, model):
    flag_image = 1
    executed_flag = False
    # read the image from disk
    image = cv2.imread(file_path)
    
    image_height, image_width, _ = image.shape
    # create blob from image
    blob = cv2.dnn.blobFromImage(image=image, size=(300, 300), mean=(104, 117, 123), swapRB=True)
    # Initialize model & set the blob to the model
    model.setInput(blob)
    # load the COCO class names
    with open('object_detection_classes_coco.txt', 'r') as f:
        class_names = f.read().split('\n')
    # get a different color array for each of the classes
    COLORS = np.random.uniform(0, 255, size=(len(class_names), 3))
    
    # forward pass through the model to carry out the detection
    output = model.forward()
      
    class_names_found = []
    non_background_pixels = 0
    x1 = 0; x2 = 0; y1 = 0; y2 = 0
    # loop over each of the detection
    for detection in output[0, 0, :, :]:
        #
        # extract the confidence of the detection
        confidence = detection[2]
        # draw bounding boxes only if the detection confidence is above...
        # ... a certain threshold, else skip 
        if confidence > .4:
            # get the class id
            class_id = detection[1]
            # map the class id to the class
            class_name = class_names[int(class_id)-1]
            color = COLORS[int(class_id)]
            class_names_found.append(class_name)
            x1 = int(detection[3] * image_width)
            y1 = int(detection[4] * image_height)
            x2 = int(detection[5] * image_width)
            y2 = int(detection[6] * image_height)
            non_background_pixels += abs(x2-x1)*abs(y2-y1) 
    # Count the non-background pixels within the bounding box region
            
    total_pixels = image.shape[0] * image.shape[1]
    
    number_objects = len(class_names_found)
    classes_string = str(class_names_found)
    percentage_background = (abs(total_pixels - non_background_pixels) / total_pixels) * 100
        
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # lur the grayscale image
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    # Calculate the average background color
    average_color = np.mean(blurred)
    # Convert the average color value to integers
    average_color = int(average_color)
    # Create a blank image of the average color
    color_image = np.zeros((100, 100, 3), np.uint8)
    color_image[:] = average_color
    # Convert the average color to RGB format
    average_color_rgb = tuple(map(int, color_image[0, 0]))
    # Print the average background color in RGB
    print("Average Background Color (RGB):", average_color_rgb)
    background_avg_color = closest_colour(average_color_rgb)
    executed_flag = True
    
    output = [number_objects, classes_string, percentage_background, background_avg_color]
    return output, executed_flag

# %% [markdown]
# ## Iterative code

# %%
folder_path =  r'C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism\images'
model = cv2.dnn.readNet(model='frozen_inference_graph.pb',
                        config='ssd_mobilenet_v2_coco_2018_03_29.pbtxt',
                        framework='TensorFlow')
iter = 0
for filename in os.listdir(folder_path):
    iter += 1
    if iter%500 == 0 or iter == 40:
        df.to_csv(f"data_{iter}.csv")
        break
    print('-------------------------------------------------------')
    print('ITER:', iter)
    print('-------------------------------------------------------')
    
    file_path = os.path.join(folder_path, filename)
    ## row that will be appended to the dataframe
    data_row = []
    data_row.append(os.path.basename(os.path.dirname(os.path.dirname(file_path))))
    print(data_row[0])
    print(os.path.dirname(os.path.dirname(file_path)))
    json_columns, flag_json = json_processing(folder_path, filename)
    print(flag_json,len(json_columns),json_columns)
    
    object_detection_columns, flag_img = object_detection(file_path, model)
    print(flag_img ,object_detection_columns)
    
    if(flag_json and flag_img):
        data_row = data_row + json_columns + object_detection_columns
        df.loc[len(df.index)] = data_row
        print(df.iloc[-1])
# Out:
# -------------------------------------------------------
# ITER: 1
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-01_12-18-16_UTC_1.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (139, 139, 139)
# True [0, '[]', 100.0, 'gray']
# -------------------------------------------------------
# ITER: 2
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-01_12-18-16_UTC_2.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (114, 114, 114)
# True [0, '[]', 100.0, 'dimgray']
# -------------------------------------------------------
# ITER: 3
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-01_12-18-16_UTC_3.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (116, 116, 116)
# True [0, '[]', 100.0, 'dimgray']
# -------------------------------------------------------
# ITER: 4
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-01_12-18-16_UTC_4.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (177, 177, 177)
# True [1, "['bird']", 81.6088, 'darkgray']
# -------------------------------------------------------
# ITER: 5
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-01_12-18-16_UTC_5.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (103, 103, 103)
# True [0, '[]', 100.0, 'dimgray']
# -------------------------------------------------------
# ITER: 6
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-01_12-18-16_UTC_6.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (107, 107, 107)
# True [2, "['teddy bear', 'bird']", 31.048, 'dimgray']
# -------------------------------------------------------
# ITER: 7
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_05-11-20_UTC_1.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (117, 117, 117)
# True [0, '[]', 100.0, 'gray']
# -------------------------------------------------------
# ITER: 8
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_05-11-20_UTC_2.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (128, 128, 128)
# True [0, '[]', 100.0, 'gray']
# -------------------------------------------------------
# ITER: 9
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_05-11-20_UTC_3.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (123, 123, 123)
# True [0, '[]', 100.0, 'gray']
# -------------------------------------------------------
# ITER: 10
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_05-11-20_UTC_4.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (130, 130, 130)
# True [0, '[]', 100.0, 'gray']
# -------------------------------------------------------
# ITER: 11
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_05-11-20_UTC_5.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (145, 145, 145)
# True [1, "['person']", 99.10900000000001, 'lightslategray']
# -------------------------------------------------------
# ITER: 12
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_05-11-20_UTC_6.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (116, 116, 116)
# True [0, '[]', 100.0, 'dimgray']
# -------------------------------------------------------
# ITER: 13
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_08-30-41_UTC_1.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (87, 87, 87)
# True [3, "['person', 'person', 'person']", 56.92283950617284, 'dimgray']
# -------------------------------------------------------
# ITER: 14
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_08-30-41_UTC_2.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (73, 73, 73)
# True [1, "['person']", 43.090020576131685, 'darkslategray']
# -------------------------------------------------------
# ITER: 15
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_08-30-41_UTC_3.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (36, 36, 36)
# True [1, "['person']", 78.13194444444444, 'darkslategray']
# -------------------------------------------------------
# ITER: 16
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_08-30-41_UTC_4.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (78, 78, 78)
# True [3, "['person', 'person', 'umbrella']", 43.226466049382715, 'darkslategray']
# -------------------------------------------------------
# ITER: 17
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_08-30-41_UTC_5.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (138, 138, 138)
# True [6, "['person', 'person', 'person', 'umbrella', 'umbrella', 'person']", 14.29295267489712, 'gray']
# -------------------------------------------------------
# ITER: 18
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_08-30-41_UTC_6.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (118, 118, 118)
# True [6, "['person', 'person', 'person', 'person', 'person', 'person']", 1.8551954732510287, 'gray']
# -------------------------------------------------------
# ITER: 19
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-02_12-47-13_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsIfjU2lUyU/ tags: 0 likes: 3417 comments: 19
# JSON processed successfully.
# True 8 ['2019-01-02', 'https://www.instagram.com/keralatourism/p/BsIfjU2lUyU/', 'Image', 'Let your dream fly higher than the kite with the festive vibe. Get ready to roll your Charkhi with colourful memories as kite festival will show different colours in the sky.\n\nhttp://www.tourism.rajasthan.gov.in/fairs-and-festivals.html\n\n#FestivalSthan #KiteFestival2019\n#MyRajasthan #PadharoMhareDesh', 0, 3417, 19, 301]
# Average Background Color (RGB): (178, 178, 178)
# True [6, "['kite', 'kite', 'kite', 'kite', 'kite', 'kite']", 67.4005, 'darkgray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-02
# instagram_link           https://www.instagram.com/keralatourism/p/BsIf...
# content_type                                                         Image
# post_description         Let your dream fly higher than the kite with t...
# number_tags                                                              0
# likes_post                                                            3417
# comments_post                                                           19
# len_description                                                        301
# number_objects                                                           6
# classes_string            ['kite', 'kite', 'kite', 'kite', 'kite', 'kite']
# background_percentage                                              67.4005
# background_avg_color                                              darkgray
# Name: 34, dtype: object
# -------------------------------------------------------
# ITER: 20
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-03_09-39-44_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsKu5B9lW9M/ tags: 0 likes: 5203 comments: 29
# JSON processed successfully.
# True 8 ['2019-01-03', 'https://www.instagram.com/keralatourism/p/BsKu5B9lW9M/', 'Image', 'Experience the Top of the World Feeling at Kumbhalgarh Fort! \nAfter the Great Wall of China, Kumbhalgarh Fort Wall is the second longest wall in the world. Come to Rajasthan and walk beside this exceptional marvel.\n\nhttp://www.tourism.rajasthan.gov.in/kumbhalgarh-fort.html\n\n#DidYouKnow #MyRajasthan #PadharoMhareDesh', 0, 5203, 29, 317]
# Average Background Color (RGB): (139, 139, 139)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-03
# instagram_link           https://www.instagram.com/keralatourism/p/BsKu...
# content_type                                                         Image
# post_description         Experience the Top of the World Feeling at Kum...
# number_tags                                                              0
# likes_post                                                            5203
# comments_post                                                           29
# len_description                                                        317
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 35, dtype: object
# -------------------------------------------------------
# ITER: 21
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-03_12-17-27_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsLA8LJFw29/ tags: 0 likes: 3885 comments: 33
# JSON processed successfully.
# True 8 ['2019-01-03', 'https://www.instagram.com/keralatourism/p/BsLA8LJFw29/', 'Image', "It's time to celebrate the pride of Rajasthan in Bikaner. \nThe colourful Camel Festival that celebrates the significance of Camels in the state is all set to take place from 12th to 13th January in Bikaner. Be there to experience true hues of desert life.\n\nwww.tourism.rajasthan.gov.in/bikaner.html\n\n#FestivalSthan #MyRajasthan #PadharoMhareDesh", 0, 3885, 33, 345]
# Average Background Color (RGB): (147, 147, 147)
# True [9, "['person', 'person', 'horse', 'horse', 'person', 'person', 'person', 'person', 'person']", 15.023800000000001, 'lightslategray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-03
# instagram_link           https://www.instagram.com/keralatourism/p/BsLA...
# content_type                                                         Image
# post_description         It's time to celebrate the pride of Rajasthan ...
# number_tags                                                              0
# likes_post                                                            3885
# comments_post                                                           33
# len_description                                                        345
# number_objects                                                           9
# classes_string           ['person', 'person', 'horse', 'horse', 'person...
# background_percentage                                              15.0238
# background_avg_color                                        lightslategray
# Name: 36, dtype: object
# -------------------------------------------------------
# ITER: 22
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-04_12-21-40_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsNmN8wl7pu/ tags: 0 likes: 3458 comments: 15
# JSON processed successfully.
# True 8 ['2019-01-04', 'https://www.instagram.com/keralatourism/p/BsNmN8wl7pu/', 'Image', 'A beautiful film that did sheer justice to the captivating beauty of Rajasthan. Come to Rajasthan and make your life Khoobsurat.\n\n#FilmSthan #MyRajasthan #PadharoMhareDesh', 0, 3458, 15, 171]
# Average Background Color (RGB): (135, 135, 135)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-04
# instagram_link           https://www.instagram.com/keralatourism/p/BsNm...
# content_type                                                         Image
# post_description         A beautiful film that did sheer justice to the...
# number_tags                                                              0
# likes_post                                                            3458
# comments_post                                                           15
# len_description                                                        171
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 37, dtype: object
# -------------------------------------------------------
# ITER: 23
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-05_04-50-21_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsPXXUNFnoo/ tags: 0 likes: 2726 comments: 12
# JSON processed successfully.
# True 8 ['2019-01-05', 'https://www.instagram.com/keralatourism/p/BsPXXUNFnoo/', 'Image', 'A weekend can fill your life with more memories than an entire year. \nCome to Sambhar in Rajasthan and handpick experiences from a basket of happiness.\n\n#WeekendSthan #MyRajasthan #PadharoMhareDesh', 0, 2726, 12, 197]
# Average Background Color (RGB): (129, 129, 129)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-05
# instagram_link           https://www.instagram.com/keralatourism/p/BsPX...
# content_type                                                         Image
# post_description         A weekend can fill your life with more memorie...
# number_tags                                                              0
# likes_post                                                            2726
# comments_post                                                           12
# len_description                                                        197
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 38, dtype: object
# -------------------------------------------------------
# ITER: 24
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-06_06-15-45_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsSF7sDljSw/ tags: 0 likes: 6036 comments: 28
# JSON processed successfully.
# True 8 ['2019-01-06', 'https://www.instagram.com/keralatourism/p/BsSF7sDljSw/', 'Image', "Let's take a ride of exhilarating experiences in Bikaner. \nThe annual Camel Festival in Bikaner which celebrates the pride of desert is all set thrill its attendees on 12th and 13th January. Be there to feel ecstatic.\n\nPicture by : @roadside_traveller\n\nhttp://www.tourism.rajasthan.gov.in/fairs-and-festivals/camel-festival.html\n\n#FestivalSthan #MyRajasthan #PadharoMhareDesh", 0, 6036, 28, 375]
# Average Background Color (RGB): (132, 132, 132)
# True [5, "['person', 'person', 'person', 'person', 'person']", 42.6547, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-06
# instagram_link           https://www.instagram.com/keralatourism/p/BsSF...
# content_type                                                         Image
# post_description         Let's take a ride of exhilarating experiences ...
# number_tags                                                              0
# likes_post                                                            6036
# comments_post                                                           28
# len_description                                                        375
# number_objects                                                           5
# classes_string           ['person', 'person', 'person', 'person', 'pers...
# background_percentage                                              42.6547
# background_avg_color                                                  gray
# Name: 39, dtype: object
# -------------------------------------------------------
# ITER: 25
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-06_11-55-10_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsSsxodlJWF/ tags: 0 likes: 2071 comments: 5
# JSON processed successfully.
# True 8 ['2019-01-06', 'https://www.instagram.com/keralatourism/p/BsSsxodlJWF/', 'Image', 'Get ready to Roll your Charkhi as the Kite Festival will reach new heights with surreal folk performances. Be there to witness the festive saga on 14th January 2019.\n\n#FestivalSthan #KiteFestival2019 #MyRajasthan #PadharoMhareDesh', 0, 2071, 5, 230]
# Average Background Color (RGB): (158, 158, 158)
# True [8, "['person', 'umbrella', 'person', 'person', 'person', 'person', 'person', 'person']", 26.485999999999997, 'darkgray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-06
# instagram_link           https://www.instagram.com/keralatourism/p/BsSs...
# content_type                                                         Image
# post_description         Get ready to Roll your Charkhi as the Kite Fes...
# number_tags                                                              0
# likes_post                                                            2071
# comments_post                                                            5
# len_description                                                        230
# number_objects                                                           8
# classes_string           ['person', 'umbrella', 'person', 'person', 'pe...
# background_percentage                                               26.486
# background_avg_color                                              darkgray
# Name: 40, dtype: object
# -------------------------------------------------------
# ITER: 26
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-07_06-13-42_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsUqffkF7-0/ tags: 0 likes: 2148 comments: 6
# JSON processed successfully.
# True 8 ['2019-01-07', 'https://www.instagram.com/keralatourism/p/BsUqffkF7-0/', 'Image', "The state has vivid shades of genres and Jaipur is all set to transform into a literal paradise with every genre of writing celebrating itself. Do you know what's coming?\n\n#LiteratureSthan #MyRajasthan #PadharoMhareDesh", 0, 2148, 6, 219]
# Average Background Color (RGB): (177, 177, 177)
# True [0, '[]', 100.0, 'darkgray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-07
# instagram_link           https://www.instagram.com/keralatourism/p/BsUq...
# content_type                                                         Image
# post_description         The state has vivid shades of genres and Jaipu...
# number_tags                                                              0
# likes_post                                                            2148
# comments_post                                                            6
# len_description                                                        219
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                              darkgray
# Name: 41, dtype: object
# -------------------------------------------------------
# ITER: 27
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-07_12-16-55_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsVUDy-F2zk/ tags: 0 likes: 2680 comments: 6
# JSON processed successfully.
# True 8 ['2019-01-07', 'https://www.instagram.com/keralatourism/p/BsVUDy-F2zk/', 'Image', 'Travel back and forth in time while staying in Bikaner.\n\nThe Lalgarh Palace and Museum in Bikaner is an architectural marvel, made entirely of red sandstone. Be here to witness an impeccable blend of Rajputana, Mughal and European architecture.\n\nhttp://www.tourism.rajasthan.gov.in/bikaner.html\n\n#MyRajasthan #PadharoMhareDesh', 0, 2680, 6, 326]
# Average Background Color (RGB): (139, 139, 139)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-07
# instagram_link           https://www.instagram.com/keralatourism/p/BsVU...
# content_type                                                         Image
# post_description         Travel back and forth in time while staying in...
# number_tags                                                              0
# likes_post                                                            2680
# comments_post                                                            6
# len_description                                                        326
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 42, dtype: object
# -------------------------------------------------------
# ITER: 28
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-08_05-29-26_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsXKON7lm0r/ tags: 0 likes: 3344 comments: 11
# JSON processed successfully.
# True 8 ['2019-01-08', 'https://www.instagram.com/keralatourism/p/BsXKON7lm0r/', 'Image', 'There are enough pages in the city of Udaipur to accommodate all the words of affection ever written or spoken. Feel the lovely vibe of Udaipur at the Literaturesthan. \n#LiteratureSthan #MyRajasthan #PadharoMhareDesh', 0, 3344, 11, 216]
# Average Background Color (RGB): (141, 141, 141)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-08
# instagram_link           https://www.instagram.com/keralatourism/p/BsXK...
# content_type                                                         Image
# post_description         There are enough pages in the city of Udaipur ...
# number_tags                                                              0
# likes_post                                                            3344
# comments_post                                                           11
# len_description                                                        216
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 43, dtype: object
# -------------------------------------------------------
# ITER: 29
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-09_06-22-51_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsZ1IRHlMMy/ tags: 0 likes: 3069 comments: 19
# JSON processed successfully.
# True 8 ['2019-01-09', 'https://www.instagram.com/keralatourism/p/BsZ1IRHlMMy/', 'Image', 'Words maybe able to connect you with God, but they definitely connect you to yourself. Come to Literaturesthan and experience what happens when the Sufi vibes of Ajmer are expressed literally.\n\n#LiteratureSthan #Sufimer #MyRajasthan #PadharoMhareDesh', 0, 3069, 19, 250]
# Average Background Color (RGB): (128, 128, 128)
# True [1, "['cake']", 51.7325, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-09
# instagram_link           https://www.instagram.com/keralatourism/p/BsZ1...
# content_type                                                         Image
# post_description         Words maybe able to connect you with God, but ...
# number_tags                                                              0
# likes_post                                                            3069
# comments_post                                                           19
# len_description                                                        250
# number_objects                                                           1
# classes_string                                                    ['cake']
# background_percentage                                              51.7325
# background_avg_color                                                  gray
# Name: 44, dtype: object
# -------------------------------------------------------
# ITER: 30
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-09_08-22-30_UTC_1.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (42, 42, 42)
# True [0, '[]', 100.0, 'darkslategray']
# -------------------------------------------------------
# ITER: 31
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-09_08-22-30_UTC_2.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (66, 66, 66)
# True [0, '[]', 100.0, 'darkslategray']
# -------------------------------------------------------
# ITER: 32
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-09_08-22-30_UTC_3.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (86, 86, 86)
# True [3, "['person', 'person', 'person']", 90.64055014680883, 'dimgray']
# -------------------------------------------------------
# ITER: 33
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-09_08-22-30_UTC_4.json
# File Not Found. Please check directory.
# False 0 []
# Average Background Color (RGB): (69, 69, 69)
# True [2, "['person', 'person']", 47.81219135802469, 'darkslategray']
# -------------------------------------------------------
# ITER: 34
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-09_11-02-46_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsaVKaLFRRK/ tags: 0 likes: 3021 comments: 10
# JSON processed successfully.
# True 8 ['2019-01-09', 'https://www.instagram.com/keralatourism/p/BsaVKaLFRRK/', 'Image', 'Stretch your arms to embrace the talent and festivity in Bikaner. \nGear up to be at the Camel Festival on 12th and 13th January where the city of Bikaner will celebrate everything that adorns the culture of Rajasthan.\n\nhttp://www.tourism.rajasthan.gov.in/fairs-and-festivals/camel-festival.html\n\n#FestivalSthan #MyRajasthan #PadharoMhareDesh', 0, 3021, 10, 341]
# Average Background Color (RGB): (141, 141, 141)
# True [1, "['person']", 59.5074, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-09
# instagram_link           https://www.instagram.com/keralatourism/p/BsaV...
# content_type                                                         Image
# post_description         Stretch your arms to embrace the talent and fe...
# number_tags                                                              0
# likes_post                                                            3021
# comments_post                                                           10
# len_description                                                        341
# number_objects                                                           1
# classes_string                                                  ['person']
# background_percentage                                              59.5074
# background_avg_color                                                  gray
# Name: 45, dtype: object
# -------------------------------------------------------
# ITER: 35
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-09_14-58-14_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsawHDdlBGn/ tags: 0 likes: 2015 comments: 5
# JSON processed successfully.
# True 8 ['2019-01-09', 'https://www.instagram.com/keralatourism/p/BsawHDdlBGn/', 'Image', 'Multiplicity in this city! \nBikaner has a lot to offer - red sandstone forts, spectacular palaces, sprawling havelis and undoubtedly its camel safaris. This city is also famous for its temples and shrines. Raj Ratan Bihari and Rasik Siromani Temple at Bikaner are religious spots that truly deserve the attention of the tourists.\n\nwww.tourism.rajasthan.gov.in/bikaner.html\n\n#MyRajasthan #PadharoMhareDesh', 0, 2015, 5, 404]
# Average Background Color (RGB): (120, 120, 120)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-09
# instagram_link           https://www.instagram.com/keralatourism/p/Bsaw...
# content_type                                                         Image
# post_description         Multiplicity in this city! \nBikaner has a lot...
# number_tags                                                              0
# likes_post                                                            2015
# comments_post                                                            5
# len_description                                                        404
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 46, dtype: object
# -------------------------------------------------------
# ITER: 36
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-10_04-54-41_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BscP1YNFadR/ tags: 0 likes: 2147 comments: 6
# JSON processed successfully.
# True 8 ['2019-01-10', 'https://www.instagram.com/keralatourism/p/BscP1YNFadR/', 'Image', 'Jaipur embraces its culture with same affection with which writers embrace their words and thoughts. Experience the preserved culture of the Pink City while you relish the art of literature at the Literaturesthan.\n\n#LiteratureSthan #Dramapur #MyRajasthan #PadharoMhareDesh', 0, 2147, 6, 272]
# Average Background Color (RGB): (125, 125, 125)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-10
# instagram_link           https://www.instagram.com/keralatourism/p/BscP...
# content_type                                                         Image
# post_description         Jaipur embraces its culture with same affectio...
# number_tags                                                              0
# likes_post                                                            2147
# comments_post                                                            6
# len_description                                                        272
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 47, dtype: object
# -------------------------------------------------------
# ITER: 37
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-10_07-59-33_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bsck_YQlbsz/ tags: 0 likes: 1472 comments: 1
# JSON processed successfully.
# True 8 ['2019-01-10', 'https://www.instagram.com/keralatourism/p/Bsck_YQlbsz/', 'Image', 'Bring some colours with you and paint the sky of Jaipur. \nThe reasons of happiness at the Kite Festival are as endless as the sky. Come to Jaipur on 14th January and fly high on experience.\n\n#FestivalSthan #MyRajasthan #PadharoMhareDesh', 0, 1472, 1, 236]
# Average Background Color (RGB): (168, 168, 168)
# True [3, "['kite', 'person', 'kite']", 92.6442, 'darkgray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-10
# instagram_link           https://www.instagram.com/keralatourism/p/Bsck...
# content_type                                                         Image
# post_description         Bring some colours with you and paint the sky ...
# number_tags                                                              0
# likes_post                                                            1472
# comments_post                                                            1
# len_description                                                        236
# number_objects                                                           3
# classes_string                                  ['kite', 'person', 'kite']
# background_percentage                                              92.6442
# background_avg_color                                              darkgray
# Name: 48, dtype: object
# -------------------------------------------------------
# ITER: 38
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-10_13-17-48_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsdJaRclvCo/ tags: 0 likes: 3904 comments: 16
# JSON processed successfully.
# True 8 ['2019-01-10', 'https://www.instagram.com/keralatourism/p/BsdJaRclvCo/', 'Image', 'Explore the royalty of Bikaner at the Gajner Palace.\n\nFounded in 1784 by Maharaja Gaj Singh ji, Gajner palace is a spectacular marvel which holds a charismatic charm and can enchant you with its mesmerising view. Visit this place to witness the royalty with beauty.\n\nwww.tourism.rajasthan.gov.in/bikaner.html\n\n#MyRajasthan #PadharoMhareDesh', 0, 3904, 16, 340]
# Average Background Color (RGB): (123, 123, 123)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-10
# instagram_link           https://www.instagram.com/keralatourism/p/BsdJ...
# content_type                                                         Image
# post_description         Explore the royalty of Bikaner at the Gajner P...
# number_tags                                                              0
# likes_post                                                            3904
# comments_post                                                           16
# len_description                                                        340
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 49, dtype: object
# -------------------------------------------------------
# ITER: 39
# -------------------------------------------------------
# rajasthan_tourism
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism
# 2019-01-11_05-08-35_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bse2ODBFyD2/ tags: 0 likes: 2880 comments: 12
# JSON processed successfully.
# True 8 ['2019-01-11', 'https://www.instagram.com/keralatourism/p/Bse2ODBFyD2/', 'Image', 'Even the dry desert of Jaisalmer is drenched in the rain of unending love for literature. Experience how stories grow in Jaisalmer by spending sometime at the Literturesthan.\n\n#LiteratureSthan #Adventuremer #MyRajasthan #PadharoMhareDesh', 0, 2880, 12, 237]
# Average Background Color (RGB): (138, 138, 138)
# True [0, '[]', 100.0, 'gray']
# handle_id                                                rajasthan_tourism
# date_posted                                                     2019-01-11
# instagram_link           https://www.instagram.com/keralatourism/p/Bse2...
# content_type                                                         Image
# post_description         Even the dry desert of Jaisalmer is drenched i...
# number_tags                                                              0
# likes_post                                                            2880
# comments_post                                                           12
# len_description                                                        237
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 50, dtype: object

# %%
folder_path =  r'C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism\images'

iter = 0
for filename in os.listdir(folder_path):
    iter += 1
    if iter%500 == 0:
        df.to_csv(f"data_{iter}.csv")
    print('-------------------------------------------------------')
    print('ITER:', iter)
    print('-------------------------------------------------------')
    
    file_path = os.path.join(folder_path, filename)
    # flag to check if code runs
    flag_image = 0
    flag_json = 0
    
    try:
        import json
        folder_path_json = r'C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism\json'
        filename_json = filename[:-3]
        filename_json = filename_json + 'json'
        filename_json_path = os.path.join(folder_path_json, filename_json)
        date = filename[0:10]

        print(filename_json) 
        with open(filename_json_path) as f:
            data = json.load(f)
        flag_json = 1 ########################### flag working OK
        shortcode = ((data['node']['shortcode']))
        instagram_link = 'https://www.instagram.com/keralatourism/p/' + str(shortcode) + '/'
        description = ((data['node']['edge_media_to_caption']['edges'][0]['node']['text']))
        description_len = len(description)
        number_tags = len(data['node']['edge_media_to_tagged_user']['edges'])
        likes_post = (data['node']['edge_media_preview_like']['count'])
        comments_post = (data['node']['edge_media_to_comment']['count'])
        is_video_flag = data['node']['is_video']
        content_type = ''
        if(is_video_flag == True):
            content_type = 'Video'
        else:
            content_type = 'Image'
        print('is_video_flag:', is_video_flag, type(is_video_flag))
        print(instagram_link, 'tags:', number_tags,'likes:', likes_post, 'comments:', comments_post)
###############################################################################################
###############################################################################################
###############################################################################################
      ###    Computer Vision Task 
        flag_image = 1
        # read the image from disk
        image = cv2.imread(file_path)
        image_height, image_width, _ = image.shape
        # create blob from image
        blob = cv2.dnn.blobFromImage(image=image, size=(300, 300), mean=(104, 117, 123), swapRB=True)
        # set the blob to the model
        model.setInput(blob)
        # forward pass through the model to carry out the detection
        output = model.forward()
          
        class_names_found = []
        non_background_pixels = 0
        x1 = 0; x2 = 0; y1 = 0; y2 = 0
        # loop over each of the detection
        for detection in output[0, 0, :, :]:
            #
            # extract the confidence of the detection
            confidence = detection[2]
            # draw bounding boxes only if the detection confidence is above...
            # ... a certain threshold, else skip 
            if confidence > .4:
                # get the class id
                class_id = detection[1]
                # map the class id to the class
                class_name = class_names[int(class_id)-1]
                color = COLORS[int(class_id)]
                class_names_found.append(class_name)
                x1 = int(detection[3] * image_width)
                y1 = int(detection[4] * image_height)
                x2 = int(detection[5] * image_width)
                y2 = int(detection[6] * image_height)
                non_background_pixels += abs(x2-x1)*abs(y2-y1) 
        # Count the non-background pixels within the bounding box region
                
        total_pixels = image.shape[0] * image.shape[1]
        
        number_objects = len(class_names_found)
        classes_string = str(class_names_found)
        percentage_background = (abs(total_pixels - non_background_pixels) / total_pixels) * 100
        
        # Convert the image to grayscale
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        # Blur the grayscale image
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)
        # Calculate the average background color
        average_color = np.mean(blurred)
        # Convert the average color value to integers
        average_color = int(average_color)
        # Create a blank image of the average color
        color_image = np.zeros((100, 100, 3), np.uint8)
        color_image[:] = average_color
        # Convert the average color to RGB format
        average_color_rgb = tuple(map(int, color_image[0, 0]))
        # Print the average background color in RGB
        print("Average Background Color (RGB):", average_color_rgb)
        
        
        def closest_colour(requested_colour):
            min_colours = {}
            for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
                r_c, g_c, b_c = webcolors.hex_to_rgb(key)
                rd = (r_c - requested_colour[0]) ** 2
                gd = (g_c - requested_colour[1]) ** 2
                bd = (b_c - requested_colour[2]) ** 2
                min_colours[(rd + gd + bd)] = name
            return min_colours[min(min_colours.keys())]
        
        background_avg_color = closest_colour(average_color_rgb)
   

        ## Output DataFrame
        print(flag_json, flag_image)
        if flag_json == 1 and flag_image == 1:
            df.loc[len(df.index)] = ['keralatourism',date, instagram_link, content_type, description, number_tags, likes_post, comments_post, description_len, 
                                   number_objects, classes_string, percentage_background, background_avg_color] 
            print(df.iloc[-1])
          # print('--------------------------------')
              
    finally:
        continue
# Out:
# -------------------------------------------------------
# ITER: 1
# -------------------------------------------------------
# 2019-01-01_12-18-16_UTC_1.json
# -------------------------------------------------------
# ITER: 2
# -------------------------------------------------------
# 2019-01-01_12-18-16_UTC_2.json
# -------------------------------------------------------
# ITER: 3
# -------------------------------------------------------
# 2019-01-01_12-18-16_UTC_3.json
# -------------------------------------------------------
# ITER: 4
# -------------------------------------------------------
# 2019-01-01_12-18-16_UTC_4.json
# -------------------------------------------------------
# ITER: 5
# -------------------------------------------------------
# 2019-01-01_12-18-16_UTC_5.json
# -------------------------------------------------------
# ITER: 6
# -------------------------------------------------------
# 2019-01-01_12-18-16_UTC_6.json
# -------------------------------------------------------
# ITER: 7
# -------------------------------------------------------
# 2019-01-02_05-11-20_UTC_1.json
# -------------------------------------------------------
# ITER: 8
# -------------------------------------------------------
# 2019-01-02_05-11-20_UTC_2.json
# -------------------------------------------------------
# ITER: 9
# -------------------------------------------------------
# 2019-01-02_05-11-20_UTC_3.json
# -------------------------------------------------------
# ITER: 10
# -------------------------------------------------------
# 2019-01-02_05-11-20_UTC_4.json
# -------------------------------------------------------
# ITER: 11
# -------------------------------------------------------
# 2019-01-02_05-11-20_UTC_5.json
# -------------------------------------------------------
# ITER: 12
# -------------------------------------------------------
# 2019-01-02_05-11-20_UTC_6.json
# -------------------------------------------------------
# ITER: 13
# -------------------------------------------------------
# 2019-01-02_08-30-41_UTC_1.json
# -------------------------------------------------------
# ITER: 14
# -------------------------------------------------------
# 2019-01-02_08-30-41_UTC_2.json
# -------------------------------------------------------
# ITER: 15
# -------------------------------------------------------
# 2019-01-02_08-30-41_UTC_3.json
# -------------------------------------------------------
# ITER: 16
# -------------------------------------------------------
# 2019-01-02_08-30-41_UTC_4.json
# -------------------------------------------------------
# ITER: 17
# -------------------------------------------------------
# 2019-01-02_08-30-41_UTC_5.json
# -------------------------------------------------------
# ITER: 18
# -------------------------------------------------------
# 2019-01-02_08-30-41_UTC_6.json
# -------------------------------------------------------
# ITER: 19
# -------------------------------------------------------
# 2019-01-02_12-47-13_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsIfjU2lUyU/ tags: 0 likes: 3417 comments: 19
# Average Background Color (RGB): (178, 178, 178)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-02
# instagram_link           https://www.instagram.com/keralatourism/p/BsIf...
# content_type                                                         Image
# post_description         Let your dream fly higher than the kite with t...
# number_tags                                                              0
# likes_post                                                            3417
# comments_post                                                           19
# len_description                                                        301
# number_objects                                                           6
# classes_string            ['kite', 'kite', 'kite', 'kite', 'kite', 'kite']
# background_percentage                                              67.4005
# background_avg_color                                              darkgray
# Name: 1, dtype: object
# -------------------------------------------------------
# ITER: 20
# -------------------------------------------------------
# 2019-01-03_09-39-44_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsKu5B9lW9M/ tags: 0 likes: 5203 comments: 29
# Average Background Color (RGB): (139, 139, 139)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-03
# instagram_link           https://www.instagram.com/keralatourism/p/BsKu...
# content_type                                                         Image
# post_description         Experience the Top of the World Feeling at Kum...
# number_tags                                                              0
# likes_post                                                            5203
# comments_post                                                           29
# len_description                                                        317
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 2, dtype: object
# -------------------------------------------------------
# ITER: 21
# -------------------------------------------------------
# 2019-01-03_12-17-27_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsLA8LJFw29/ tags: 0 likes: 3885 comments: 33
# Average Background Color (RGB): (147, 147, 147)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-03
# instagram_link           https://www.instagram.com/keralatourism/p/BsLA...
# content_type                                                         Image
# post_description         It's time to celebrate the pride of Rajasthan ...
# number_tags                                                              0
# likes_post                                                            3885
# comments_post                                                           33
# len_description                                                        345
# number_objects                                                           9
# classes_string           ['person', 'person', 'horse', 'horse', 'person...
# background_percentage                                              15.0238
# background_avg_color                                        lightslategray
# Name: 3, dtype: object
# -------------------------------------------------------
# ITER: 22
# -------------------------------------------------------
# 2019-01-04_12-21-40_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsNmN8wl7pu/ tags: 0 likes: 3458 comments: 15
# Average Background Color (RGB): (135, 135, 135)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-04
# instagram_link           https://www.instagram.com/keralatourism/p/BsNm...
# content_type                                                         Image
# post_description         A beautiful film that did sheer justice to the...
# number_tags                                                              0
# likes_post                                                            3458
# comments_post                                                           15
# len_description                                                        171
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 4, dtype: object
# -------------------------------------------------------
# ITER: 23
# -------------------------------------------------------
# 2019-01-05_04-50-21_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsPXXUNFnoo/ tags: 0 likes: 2726 comments: 12
# Average Background Color (RGB): (129, 129, 129)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-05
# instagram_link           https://www.instagram.com/keralatourism/p/BsPX...
# content_type                                                         Image
# post_description         A weekend can fill your life with more memorie...
# number_tags                                                              0
# likes_post                                                            2726
# comments_post                                                           12
# len_description                                                        197
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 5, dtype: object
# -------------------------------------------------------
# ITER: 24
# -------------------------------------------------------
# 2019-01-06_06-15-45_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsSF7sDljSw/ tags: 0 likes: 6036 comments: 28
# Average Background Color (RGB): (132, 132, 132)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-06
# instagram_link           https://www.instagram.com/keralatourism/p/BsSF...
# content_type                                                         Image
# post_description         Let's take a ride of exhilarating experiences ...
# number_tags                                                              0
# likes_post                                                            6036
# comments_post                                                           28
# len_description                                                        375
# number_objects                                                           5
# classes_string           ['person', 'person', 'person', 'person', 'pers...
# background_percentage                                              42.8997
# background_avg_color                                                  gray
# Name: 6, dtype: object
# -------------------------------------------------------
# ITER: 25
# -------------------------------------------------------
# 2019-01-06_11-55-10_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsSsxodlJWF/ tags: 0 likes: 2071 comments: 5
# Average Background Color (RGB): (158, 158, 158)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-06
# instagram_link           https://www.instagram.com/keralatourism/p/BsSs...
# content_type                                                         Image
# post_description         Get ready to Roll your Charkhi as the Kite Fes...
# number_tags                                                              0
# likes_post                                                            2071
# comments_post                                                            5
# len_description                                                        230
# number_objects                                                           8
# classes_string           ['person', 'umbrella', 'person', 'person', 'pe...
# background_percentage                                               26.486
# background_avg_color                                              darkgray
# Name: 7, dtype: object
# -------------------------------------------------------
# ITER: 26
# -------------------------------------------------------
# 2019-01-07_06-13-42_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsUqffkF7-0/ tags: 0 likes: 2148 comments: 6
# Average Background Color (RGB): (177, 177, 177)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-07
# instagram_link           https://www.instagram.com/keralatourism/p/BsUq...
# content_type                                                         Image
# post_description         The state has vivid shades of genres and Jaipu...
# number_tags                                                              0
# likes_post                                                            2148
# comments_post                                                            6
# len_description                                                        219
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                              darkgray
# Name: 8, dtype: object
# -------------------------------------------------------
# ITER: 27
# -------------------------------------------------------
# 2019-01-07_12-16-55_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsVUDy-F2zk/ tags: 0 likes: 2680 comments: 6
# Average Background Color (RGB): (139, 139, 139)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-07
# instagram_link           https://www.instagram.com/keralatourism/p/BsVU...
# content_type                                                         Image
# post_description         Travel back and forth in time while staying in...
# number_tags                                                              0
# likes_post                                                            2680
# comments_post                                                            6
# len_description                                                        326
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 9, dtype: object
# -------------------------------------------------------
# ITER: 28
# -------------------------------------------------------
# 2019-01-08_05-29-26_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsXKON7lm0r/ tags: 0 likes: 3344 comments: 11
# Average Background Color (RGB): (141, 141, 141)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-08
# instagram_link           https://www.instagram.com/keralatourism/p/BsXK...
# content_type                                                         Image
# post_description         There are enough pages in the city of Udaipur ...
# number_tags                                                              0
# likes_post                                                            3344
# comments_post                                                           11
# len_description                                                        216
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 10, dtype: object
# -------------------------------------------------------
# ITER: 29
# -------------------------------------------------------
# 2019-01-09_06-22-51_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsZ1IRHlMMy/ tags: 0 likes: 3069 comments: 19
# Average Background Color (RGB): (128, 128, 128)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-09
# instagram_link           https://www.instagram.com/keralatourism/p/BsZ1...
# content_type                                                         Image
# post_description         Words maybe able to connect you with God, but ...
# number_tags                                                              0
# likes_post                                                            3069
# comments_post                                                           19
# len_description                                                        250
# number_objects                                                           1
# classes_string                                                    ['cake']
# background_percentage                                            57.127187
# background_avg_color                                                  gray
# Name: 11, dtype: object
# -------------------------------------------------------
# ITER: 30
# -------------------------------------------------------
# 2019-01-09_08-22-30_UTC_1.json
# -------------------------------------------------------
# ITER: 31
# -------------------------------------------------------
# 2019-01-09_08-22-30_UTC_2.json
# -------------------------------------------------------
# ITER: 32
# -------------------------------------------------------
# 2019-01-09_08-22-30_UTC_3.json
# -------------------------------------------------------
# ITER: 33
# -------------------------------------------------------
# 2019-01-09_08-22-30_UTC_4.json
# -------------------------------------------------------
# ITER: 34
# -------------------------------------------------------
# 2019-01-09_11-02-46_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsaVKaLFRRK/ tags: 0 likes: 3021 comments: 10
# Average Background Color (RGB): (141, 141, 141)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-09
# instagram_link           https://www.instagram.com/keralatourism/p/BsaV...
# content_type                                                         Image
# post_description         Stretch your arms to embrace the talent and fe...
# number_tags                                                              0
# likes_post                                                            3021
# comments_post                                                           10
# len_description                                                        341
# number_objects                                                           1
# classes_string                                                  ['person']
# background_percentage                                              59.5074
# background_avg_color                                                  gray
# Name: 12, dtype: object
# -------------------------------------------------------
# ITER: 35
# -------------------------------------------------------
# 2019-01-09_14-58-14_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsawHDdlBGn/ tags: 0 likes: 2015 comments: 5
# Average Background Color (RGB): (120, 120, 120)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-09
# instagram_link           https://www.instagram.com/keralatourism/p/Bsaw...
# content_type                                                         Image
# post_description         Multiplicity in this city! \nBikaner has a lot...
# number_tags                                                              0
# likes_post                                                            2015
# comments_post                                                            5
# len_description                                                        404
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 13, dtype: object
# -------------------------------------------------------
# ITER: 36
# -------------------------------------------------------
# 2019-01-10_04-54-41_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BscP1YNFadR/ tags: 0 likes: 2147 comments: 6
# Average Background Color (RGB): (125, 125, 125)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-10
# instagram_link           https://www.instagram.com/keralatourism/p/BscP...
# content_type                                                         Image
# post_description         Jaipur embraces its culture with same affectio...
# number_tags                                                              0
# likes_post                                                            2147
# comments_post                                                            6
# len_description                                                        272
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 14, dtype: object
# -------------------------------------------------------
# ITER: 37
# -------------------------------------------------------
# 2019-01-10_07-59-33_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bsck_YQlbsz/ tags: 0 likes: 1472 comments: 1
# Average Background Color (RGB): (168, 168, 168)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-10
# instagram_link           https://www.instagram.com/keralatourism/p/Bsck...
# content_type                                                         Image
# post_description         Bring some colours with you and paint the sky ...
# number_tags                                                              0
# likes_post                                                            1472
# comments_post                                                            1
# len_description                                                        236
# number_objects                                                           3
# classes_string                                  ['kite', 'person', 'kite']
# background_percentage                                              92.6442
# background_avg_color                                              darkgray
# Name: 15, dtype: object
# -------------------------------------------------------
# ITER: 38
# -------------------------------------------------------
# 2019-01-10_13-17-48_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsdJaRclvCo/ tags: 0 likes: 3904 comments: 16
# Average Background Color (RGB): (123, 123, 123)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-10
# instagram_link           https://www.instagram.com/keralatourism/p/BsdJ...
# content_type                                                         Image
# post_description         Explore the royalty of Bikaner at the Gajner P...
# number_tags                                                              0
# likes_post                                                            3904
# comments_post                                                           16
# len_description                                                        340
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 16, dtype: object
# -------------------------------------------------------
# ITER: 39
# -------------------------------------------------------
# 2019-01-11_05-08-35_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bse2ODBFyD2/ tags: 0 likes: 2880 comments: 12
# Average Background Color (RGB): (138, 138, 138)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-11
# instagram_link           https://www.instagram.com/keralatourism/p/Bse2...
# content_type                                                         Image
# post_description         Even the dry desert of Jaisalmer is drenched i...
# number_tags                                                              0
# likes_post                                                            2880
# comments_post                                                           12
# len_description                                                        237
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 17, dtype: object
# -------------------------------------------------------
# ITER: 40
# -------------------------------------------------------
# 2019-01-11_10-30-47_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsfbF-EFUV-/ tags: 0 likes: 2309 comments: 18
# Average Background Color (RGB): (58, 58, 58)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-11
# instagram_link           https://www.instagram.com/keralatourism/p/Bsfb...
# content_type                                                         Image
# post_description         Bring some colours with you and paint the sky ...
# number_tags                                                              0
# likes_post                                                            2309
# comments_post                                                           18
# len_description                                                        331
# number_objects                                                           1
# classes_string                                                  ['orange']
# background_percentage                                               96.199
# background_avg_color                                         darkslategray
# Name: 18, dtype: object
# -------------------------------------------------------
# ITER: 41
# -------------------------------------------------------
# 2019-01-11_12-26-00_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsfoR2tFa-J/ tags: 0 likes: 1041 comments: 0
# Average Background Color (RGB): (163, 163, 163)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-11
# instagram_link           https://www.instagram.com/keralatourism/p/Bsfo...
# content_type                                                         Image
# post_description         Send the festive vibes inside a cultural envel...
# number_tags                                                              0
# likes_post                                                            1041
# comments_post                                                            0
# len_description                                                        174
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                              darkgray
# Name: 19, dtype: object
# -------------------------------------------------------
# ITER: 42
# -------------------------------------------------------
# 2019-01-11_13-59-45_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsfzAeBFNIO/ tags: 0 likes: 2375 comments: 6
# Average Background Color (RGB): (132, 132, 132)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-11
# instagram_link           https://www.instagram.com/keralatourism/p/Bsfz...
# content_type                                                         Image
# post_description         Witness the memories of those who lived with s...
# number_tags                                                              0
# likes_post                                                            2375
# comments_post                                                            6
# len_description                                                        400
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 20, dtype: object
# -------------------------------------------------------
# ITER: 43
# -------------------------------------------------------
# 2019-01-12_07-25-38_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BshqsrjF_W_/ tags: 0 likes: 3119 comments: 8
# Average Background Color (RGB): (134, 134, 134)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-12
# instagram_link           https://www.instagram.com/keralatourism/p/Bshq...
# content_type                                                         Image
# post_description         The World Says Khamma Ghani to the Bikaner Cam...
# number_tags                                                              0
# likes_post                                                            3119
# comments_post                                                            8
# len_description                                                        111
# number_objects                                                           8
# classes_string           ['person', 'person', 'person', 'person', 'pers...
# background_percentage                                            40.520688
# background_avg_color                                                  gray
# Name: 21, dtype: object
# -------------------------------------------------------
# ITER: 44
# -------------------------------------------------------
# 2019-01-12_10-19-32_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bsh-mZGlnB8/ tags: 0 likes: 1919 comments: 11
# Average Background Color (RGB): (111, 111, 111)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-12
# instagram_link           https://www.instagram.com/keralatourism/p/Bsh-...
# content_type                                                         Image
# post_description         #Bikaner is a city that considers literature t...
# number_tags                                                              0
# likes_post                                                            1919
# comments_post                                                           11
# len_description                                                        251
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                               dimgray
# Name: 22, dtype: object
# -------------------------------------------------------
# ITER: 45
# -------------------------------------------------------
# 2019-01-12_10-44-53_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsiBgFpl-Br/ tags: 0 likes: 4864 comments: 23
# Average Background Color (RGB): (162, 162, 162)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-12
# instagram_link           https://www.instagram.com/keralatourism/p/BsiB...
# content_type                                                         Image
# post_description         As I sit there to witness my day, I thank you ...
# number_tags                                                              0
# likes_post                                                            4864
# comments_post                                                           23
# len_description                                                        133
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                              darkgray
# Name: 23, dtype: object
# -------------------------------------------------------
# ITER: 46
# -------------------------------------------------------
# 2019-01-12_12-00-57_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BsiKNOxF3Wq/ tags: 0 likes: 7178 comments: 35
# Average Background Color (RGB): (103, 103, 103)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-12
# instagram_link           https://www.instagram.com/keralatourism/p/BsiK...
# content_type                                                         Image
# post_description         The Fur Cutting Competition at the #BikanerCam...
# number_tags                                                              0
# likes_post                                                            7178
# comments_post                                                           35
# len_description                                                        273
# number_objects                                                           2
# classes_string                                      ['person', 'elephant']
# background_percentage                                            24.598016
# background_avg_color                                               dimgray
# Name: 24, dtype: object
# -------------------------------------------------------
# ITER: 47
# -------------------------------------------------------
# 2019-01-13_05-47-06_UTC_1.json
# -------------------------------------------------------
# ITER: 48
# -------------------------------------------------------
# 2019-01-13_05-47-06_UTC_2.json
# -------------------------------------------------------
# ITER: 49
# -------------------------------------------------------
# 2019-01-13_05-47-06_UTC_3.json
# -------------------------------------------------------
# ITER: 50
# -------------------------------------------------------
# 2019-01-13_06-45-29_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BskK5kildQu/ tags: 0 likes: 4059 comments: 18
# Average Background Color (RGB): (84, 84, 84)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-13
# instagram_link           https://www.instagram.com/keralatourism/p/BskK...
# content_type                                                         Image
# post_description         May you sow the seeds of hopes and harvest hap...
# number_tags                                                              0
# likes_post                                                            4059
# comments_post                                                           18
# len_description                                                        162
# number_objects                                                           1
# classes_string                                                  ['person']
# background_percentage                                               81.769
# background_avg_color                                               dimgray
# Name: 25, dtype: object
# -------------------------------------------------------
# ITER: 51
# -------------------------------------------------------
# 2019-01-13_09-58-15_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bskg9ZClhpq/ tags: 0 likes: 10542 comments: 36
# Average Background Color (RGB): (115, 115, 115)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-13
# instagram_link           https://www.instagram.com/keralatourism/p/Bskg...
# content_type                                                         Image
# post_description         Taking culture to the top and talent to the ne...
# number_tags                                                              0
# likes_post                                                           10542
# comments_post                                                           36
# len_description                                                        226
# number_objects                                                           1
# classes_string                                                  ['person']
# background_percentage                                            92.404557
# background_avg_color                                               dimgray
# Name: 26, dtype: object
# -------------------------------------------------------
# ITER: 52
# -------------------------------------------------------
# 2019-01-13_12-20-14_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BskxNXZlkBH/ tags: 0 likes: 3369 comments: 9
# Average Background Color (RGB): (143, 143, 143)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-13
# instagram_link           https://www.instagram.com/keralatourism/p/Bskx...
# content_type                                                         Image
# post_description         Beauty knows no limits at the Bikaner Camel Fe...
# number_tags                                                              0
# likes_post                                                            3369
# comments_post                                                            9
# len_description                                                        166
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 27, dtype: object
# -------------------------------------------------------
# ITER: 53
# -------------------------------------------------------
# 2019-01-15_06-10-59_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BspQimMlWLk/ tags: 0 likes: 5644 comments: 217
# Average Background Color (RGB): (172, 172, 172)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-15
# instagram_link           https://www.instagram.com/keralatourism/p/BspQ...
# content_type                                                         Image
# post_description         It's a palace in the middle of the Man Sagar L...
# number_tags                                                              0
# likes_post                                                            5644
# comments_post                                                          217
# len_description                                                        252
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                              darkgray
# Name: 28, dtype: object
# -------------------------------------------------------
# ITER: 54
# -------------------------------------------------------
# 2019-01-15_10-30-51_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BspuR4LnePT/ tags: 0 likes: 3344 comments: 31
# Average Background Color (RGB): (155, 155, 155)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-15
# instagram_link           https://www.instagram.com/keralatourism/p/Bspu...
# content_type                                                         Image
# post_description         The temple is 600 years old and it is widely b...
# number_tags                                                              0
# likes_post                                                            3344
# comments_post                                                           31
# len_description                                                        409
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                              darkgray
# Name: 29, dtype: object
# -------------------------------------------------------
# ITER: 55
# -------------------------------------------------------
# 2019-01-15_12-44-11_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bsp9ihFHpvM/ tags: 0 likes: 6053 comments: 374
# Average Background Color (RGB): (225, 225, 225)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-15
# instagram_link           https://www.instagram.com/keralatourism/p/Bsp9...
# content_type                                                         Image
# post_description         With a hint of Rajasthan’s glory,\nBe the hero...
# number_tags                                                              0
# likes_post                                                            6053
# comments_post                                                          374
# len_description                                                        113
# number_objects                                                           1
# classes_string                                                    ['book']
# background_percentage                                             7.996656
# background_avg_color                                             gainsboro
# Name: 30, dtype: object
# -------------------------------------------------------
# ITER: 56
# -------------------------------------------------------
# 2019-01-16_09-51-54_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/BssOniClKQM/ tags: 0 likes: 1477 comments: 11
# Average Background Color (RGB): (147, 147, 147)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-16
# instagram_link           https://www.instagram.com/keralatourism/p/BssO...
# content_type                                                         Image
# post_description         A story a day, keeps reality at bay! \nConnect...
# number_tags                                                              0
# likes_post                                                            1477
# comments_post                                                           11
# len_description                                                        182
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                        lightslategray
# Name: 31, dtype: object
# -------------------------------------------------------
# ITER: 57
# -------------------------------------------------------
# 2019-01-17_10-57-08_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bsu64Mwlxim/ tags: 0 likes: 3321 comments: 11
# Average Background Color (RGB): (119, 119, 119)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-17
# instagram_link           https://www.instagram.com/keralatourism/p/Bsu6...
# content_type                                                         Image
# post_description         Spend sometime amidst the blend of aristrocrac...
# number_tags                                                              0
# likes_post                                                            3321
# comments_post                                                           11
# len_description                                                        230
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 32, dtype: object
# -------------------------------------------------------
# ITER: 58
# -------------------------------------------------------
# 2019-01-18_03-59-49_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bswv6jxFzgk/ tags: 0 likes: 2166 comments: 18
# Average Background Color (RGB): (170, 170, 170)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-18
# instagram_link           https://www.instagram.com/keralatourism/p/Bswv...
# content_type                                                         Image
# post_description         Bring out a renaissance of emotions, through p...
# number_tags                                                              0
# likes_post                                                            2166
# comments_post                                                           18
# len_description                                                        277
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                              darkgray
# Name: 33, dtype: object
# -------------------------------------------------------
# ITER: 59
# -------------------------------------------------------
# 2019-01-18_13-44-49_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/Bsxy3PpFr5l/ tags: 0 likes: 1420 comments: 11
# Average Background Color (RGB): (147, 147, 147)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2019-01-18
# ...
# instagram_link           https://www.instagram.com/keralatourism/p/CgJ5...
# content_type                                                         Image
# post_description         Ek Ehsaas Sanyog ka!\n#RajasthanEkEhsaas\n\nEx...
# number_tags                                                              0
# likes_post                                                            1318
# comments_post                                                            5
# len_description                                                        338
# number_objects                                                           3
# classes_string                                 ['person', 'person', 'bed']
# background_percentage                                             3.437243
# background_avg_color                                                  gray
# Name: 2722, dtype: object
# -------------------------------------------------------
# ITER: 4594
# -------------------------------------------------------
# 2022-07-19_04-39-00_UTC_1.json
# -------------------------------------------------------
# ITER: 4595
# -------------------------------------------------------
# 2022-07-19_04-39-00_UTC_2.json
# -------------------------------------------------------
# ITER: 4596
# -------------------------------------------------------
# 2022-07-19_04-39-00_UTC_3.json
# -------------------------------------------------------
# ITER: 4597
# -------------------------------------------------------
# 2022-07-19_04-39-00_UTC_4.json
# -------------------------------------------------------
# ITER: 4598
# -------------------------------------------------------
# 2022-07-19_09-06-54_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgMC9_DFta6/ tags: 2 likes: 852 comments: 5
# Average Background Color (RGB): (154, 154, 154)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-19
# instagram_link           https://www.instagram.com/keralatourism/p/CgMC...
# content_type                                                         Image
# post_description         Discover New Destinations ~ Visit RDTM 2022, t...
# number_tags                                                              2
# likes_post                                                             852
# comments_post                                                            5
# len_description                                                        712
# number_objects                                                           2
# classes_string                                          ['person', 'boat']
# background_percentage                                            35.871056
# background_avg_color                                              darkgray
# Name: 2723, dtype: object
# -------------------------------------------------------
# ITER: 4599
# -------------------------------------------------------
# 2022-07-20_05-06-08_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgOMNXGNHHe/ tags: 0 likes: 2791 comments: 11
# Average Background Color (RGB): (66, 66, 66)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-20
# instagram_link           https://www.instagram.com/keralatourism/p/CgOM...
# content_type                                                         Image
# post_description         The Garh Ganesh Temple stands in its entire sp...
# number_tags                                                              0
# likes_post                                                            2791
# comments_post                                                           11
# len_description                                                        423
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                         darkslategray
# Name: 2724, dtype: object
# -------------------------------------------------------
# ITER: 4600
# -------------------------------------------------------
# 2022-07-20_08-31-53_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgOjwR2N53g/ tags: 1 likes: 2861 comments: 23
# Average Background Color (RGB): (155, 155, 155)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-20
# instagram_link           https://www.instagram.com/keralatourism/p/CgOj...
# content_type                                                         Image
# post_description         Jaipur is ready to kick off the Rajasthan Dome...
# number_tags                                                              1
# likes_post                                                            2861
# comments_post                                                           23
# len_description                                                        436
# number_objects                                                           2
# classes_string                                        ['person', 'person']
# background_percentage                                            70.808385
# background_avg_color                                              darkgray
# Name: 2725, dtype: object
# -------------------------------------------------------
# ITER: 4601
# -------------------------------------------------------
# 2022-07-21_04-51-08_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgQvSclNE-b/ tags: 0 likes: 2436 comments: 15
# Average Background Color (RGB): (92, 92, 92)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-21
# instagram_link           https://www.instagram.com/keralatourism/p/CgQv...
# content_type                                                         Image
# post_description         Dhundleshwar Mahadev Waterfall in Talwas, Bund...
# number_tags                                                              0
# likes_post                                                            2436
# comments_post                                                           15
# len_description                                                        391
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                               dimgray
# Name: 2726, dtype: object
# -------------------------------------------------------
# ITER: 4602
# -------------------------------------------------------
# 2022-07-23_03-02-30_UTC_1.json
# -------------------------------------------------------
# ITER: 4603
# -------------------------------------------------------
# 2022-07-23_03-02-30_UTC_2.json
# -------------------------------------------------------
# ITER: 4604
# -------------------------------------------------------
# 2022-07-23_03-02-30_UTC_3.json
# -------------------------------------------------------
# ITER: 4605
# -------------------------------------------------------
# 2022-07-23_14-04-13_UTC_1.json
# -------------------------------------------------------
# ITER: 4606
# -------------------------------------------------------
# 2022-07-23_14-04-13_UTC_2.json
# -------------------------------------------------------
# ITER: 4607
# -------------------------------------------------------
# 2022-07-23_14-04-13_UTC_3.json
# -------------------------------------------------------
# ITER: 4608
# -------------------------------------------------------
# 2022-07-24_08-46-23_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgY4l_EvBDS/ tags: 0 likes: 3468 comments: 19
# Average Background Color (RGB): (127, 127, 127)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-24
# instagram_link           https://www.instagram.com/keralatourism/p/CgY4...
# content_type                                                         Image
# post_description         The magnificent edifice you are viewing from t...
# number_tags                                                              0
# likes_post                                                            3468
# comments_post                                                           19
# len_description                                                        339
# number_objects                                                           1
# classes_string                                                     ['cat']
# background_percentage                                             9.593278
# background_avg_color                                                  gray
# Name: 2727, dtype: object
# -------------------------------------------------------
# ITER: 4609
# -------------------------------------------------------
# 2022-07-25_05-50-26_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgbJQQhv8uK/ tags: 0 likes: 4029 comments: 25
# Average Background Color (RGB): (117, 117, 117)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-25
# instagram_link           https://www.instagram.com/keralatourism/p/CgbJ...
# content_type                                                         Image
# post_description         The monsoon season in Rajasthan makes Banswara...
# number_tags                                                              0
# likes_post                                                            4029
# comments_post                                                           25
# len_description                                                        236
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 2728, dtype: object
# -------------------------------------------------------
# ITER: 4610
# -------------------------------------------------------
# 2022-07-26_05-02-39_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgdolJ_tS5C/ tags: 0 likes: 1985 comments: 9
# Average Background Color (RGB): (133, 133, 133)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-26
# instagram_link           https://www.instagram.com/keralatourism/p/Cgdo...
# content_type                                                         Image
# post_description         Ek Ehsaas Shudhta ka!\n#RajasthanEkEhsaas\n\nC...
# number_tags                                                              0
# likes_post                                                            1985
# comments_post                                                            9
# len_description                                                        320
# number_objects                                                           1
# classes_string                                                  ['person']
# background_percentage                                            48.589678
# background_avg_color                                                  gray
# Name: 2729, dtype: object
# -------------------------------------------------------
# ITER: 4611
# -------------------------------------------------------
# 2022-07-26_13-33-53_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CgejFdzt5nW/ tags: 0 likes: 949 comments: 3
# Average Background Color (RGB): (93, 93, 93)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-26
# instagram_link           https://www.instagram.com/keralatourism/p/Cgej...
# content_type                                                         Image
# post_description         Rajasthan Tourism is ready to engage in the fo...
# number_tags                                                              0
# likes_post                                                             949
# comments_post                                                            3
# len_description                                                        401
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                               dimgray
# Name: 2730, dtype: object
# -------------------------------------------------------
# ITER: 4612
# -------------------------------------------------------
# 2022-07-27_09-39-04_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CggtAgktQbW/ tags: 0 likes: 2851 comments: 23
# Average Background Color (RGB): (92, 92, 92)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-27
# instagram_link           https://www.instagram.com/keralatourism/p/Cggt...
# content_type                                                         Image
# post_description         If you are a nature lover, Padajhar Waterfall ...
# number_tags                                                              0
# likes_post                                                            2851
# comments_post                                                           23
# len_description                                                        384
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                               dimgray
# Name: 2731, dtype: object
# -------------------------------------------------------
# ITER: 4613
# -------------------------------------------------------
# 2022-07-29_04-38-20_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CglULqGNvY0/ tags: 0 likes: 1471 comments: 3
# Average Background Color (RGB): (131, 131, 131)
# 1 1
# handle_id                                                    keralatourism
# date_posted                                                     2022-07-29
# instagram_link           https://www.instagram.com/keralatourism/p/CglU...
# content_type                                                         Image
# post_description         Different shades of green and blue in one fram...
# number_tags                                                              0
# likes_post                                                            1471
# comments_post                                                            3
# len_description                                                        380
# number_objects                                                           0
# classes_string                                                          []
# background_percentage                                                100.0
# background_avg_color                                                  gray
# Name: 2732, dtype: object
# -------------------------------------------------------
# ITER: 4614
# -------------------------------------------------------
# 2022-07-29_08-44-39_UTC.json
# is_video_flag: False <class 'bool'>
# https://www.instagram.com/keralatourism/p/CglwXxSNqR6/ tags: 0 likes: 1384 comments: 5

# %%
df.to_csv('rajasthan_tourism_out2.csv')

# %%
df.tail()
# Out:
#           handle_id date_posted  \
# 3014  keralatourism  2023-06-06
# 3015  keralatourism  2023-06-07
# 3016  keralatourism  2023-06-10
# 3017  keralatourism  2023-06-14
# 3018  keralatourism  2023-06-15
#
#                                          instagram_link content_type  \
# 3014  https://www.instagram.com/keralatourism/p/CtIv...        Image
# 3015  https://www.instagram.com/keralatourism/p/CtLT...        Image
# 3016  https://www.instagram.com/keralatourism/p/CtT3...        Image
# 3017  https://www.instagram.com/keralatourism/p/CtdV...        Image
# 3018  https://www.instagram.com/keralatourism/p/Ctf6...        Image
#
#                                        post_description  number_tags  \
# 3014  Ek Ehsaas Banawat Ka!\n#RajasthanEkEhsaas\n\nI...            0
# 3015  Delve into the captivating and triumphant past...            0
# 3016  Rajasthan's Jharokhas are exquisite and intric...            0
# 3017  Delve into the captivating world of Rajasthan'...            0
# 3018  Jhalana Leopard Safari in Jaipur is home to ov...            1
#
#       likes_post  comments_post  len_description  number_objects  \
# 3014        1861             15              457               2
# 3015        1299              7              396               1
# 3016         816              4              469               0
# 3017        1174              8              533               1
# 3018         768              5              629               0
#
#                 classes_string  background_percentage background_avg_color
# 3014  ['person', 'teddy bear']               1.143144             darkgray
# 3015                ['person']              84.016804             darkgray
# 3016                        []             100.000000              dimgray
# 3017                ['person']              88.826046             darkgray
# 3018                        []             100.000000                 gray

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3019 entries, 0 to 3018
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   handle_id              3019 non-null   object
#  1   date_posted            3019 non-null   object
#  2   instagram_link         3019 non-null   object
#  3   content_type           3019 non-null   object
#  4   post_description       3019 non-null   object
#  5   number_tags            3019 non-null   int64
#  6   likes_post             3019 non-null   int64
#  7   comments_post          3019 non-null   int64
#  8   len_description        3019 non-null   int64
#  9   number_objects         3019 non-null   int64
#  10  classes_string         3019 non-null   object
#  11  background_percentage  3019 non-null   float64
#  12  background_avg_color   3019 non-null   object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 330.2+ KB
