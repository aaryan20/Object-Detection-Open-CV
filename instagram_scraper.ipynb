# %%
# !pip3 install instaloader

# %%
pwd
# Out:
# 'C:\\Users\\aaryan\\projkts\\iim_ngp\\instagram_scrape'

# %%
mkdir rajasthan_tourism
# Out:
# A subdirectory or file rajasthan_tourism already exists.

# %%
cd rajasthan_tourism
# Out:
# C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism

# %%
from datetime import datetime
from itertools import dropwhile, takewhile

import instaloader

L = instaloader.Instaloader(download_pictures=True, download_videos=False,
                            download_video_thumbnails=False,max_connection_attempts=30)
L.login('bbababji', 'aWNDABUDOAWBDOB1')        # (login)


posts = instaloader.Profile.from_username(L.context, "rajasthan_tourism").get_posts()

SINCE = datetime(2019, 1, 1)
UNTIL = datetime(2023, 17, 6)

for post in takewhile(lambda p: p.date > UNTIL, dropwhile(lambda p: p.date > SINCE, posts)):
    print(post.date)
    L.download_post(post, "rajasthan_tourism")
# Out:
# ---------------------------------------------------------------------------
# ConnectionException                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9308\1840377939.py in <module>
#       6 L = instaloader.Instaloader(download_pictures=True, download_videos=False,
#       7                             download_video_thumbnails=False,max_connection_attempts=30)
# ----> 8 L.login('bbababji', 'aWNDABUDOAWBDOB1')        # (login)
#       9
#      10
#
# ~\anaconda3\lib\site-packages\instaloader\instaloader.py in login(self, user, passwd)
#     632         :raises TwoFactorAuthRequiredException: First step of 2FA login done, now call
#     633            :meth:`Instaloader.two_factor_login`."""
# --> 634         self.context.login(user, passwd)
#     635
#     636     def two_factor_login(self, two_factor_code) -> None:
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in login(self, user, passwd)
# ...

# %%
import instaloader
profile_name = "rajasthan_tourism"

L = instaloader.Instaloader(download_pictures=True, download_videos=False,
                            download_video_thumbnails=False,max_connection_attempts=30)

L.download_profile(profile_name, profile_pic_only=False)
# Out:
# Stored ID 2110295149 for profile rajasthan_tourism.
# rajasthan_tourism\2022-08-16_10-32-53_UTC_profile_pic.jpg
# Retrieving posts from profile rajasthan_tourism.
# [   1/5916] rajasthan_tourism\2023-06-16_12-28-49_UTC_1.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_2.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_3.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_4.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_5.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_6.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_7.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_8.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_9.jpg rajasthan_tourism\2023-06-16_12-28-49_UTC_10.jpg [Mehrangarh Fort in Jodhpur is…] json
# [   2/5916] rajasthan_tourism\2023-06-16_05-18-52_UTC_1.jpg rajasthan_tourism\2023-06-16_05-18-52_UTC_2.jpg [Experience the divine glory o…] json
# [   3/5916] [Experience the captivating cu…] json
# [   4/5916] rajasthan_tourism\2023-06-15_05-06-07_UTC.jpg [Jhalana Leopard Safari in Jai…] json
# ...

# %%
# shutil.copyfile(src, dst)

# 2nd option
# shutil.copy(src, dst)

# %%
import os
import shutil


folder_path = r'C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism\rajasthan_tourism'
dst = r'C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism\json'

iter = 0
arr = ['9','0','1', '2', '3']
       
for filename in os.listdir(folder_path):
    if((filename[3] in arr) and (filename[-1] == 'z')):
        folder_path = r'C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism\rajasthan_tourism'
        src = folder_path + '\\' + filename
        dst = r'C:\Users\aaryan\projkts\iim_ngp\instagram_scrape\rajasthan_tourism\json'
        dst += '\\' + filename
        shutil.copyfile(src, dst)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2AAB-3CB0
#
#  Directory of C:\Users\aaryan\kerala_tourism
#
# 10-05-2023  16:27    <DIR>          .
# 10-05-2023  16:27    <DIR>          ..
# 10-05-2023  17:07    <DIR>          keralatourism
#                0 File(s)              0 bytes
#                3 Dir(s)  232,985,407,488 bytes free

# %%
mkdir kerala_tourism2

# %%
cd kerala_tourism2
# Out:
# C:\Users\aaryan\kerala_tourism\kerala_tourism2

# %%
# 21-03-2017
# 24-Nov-2015

from datetime import datetime
from itertools import dropwhile, takewhile

import instaloader

L = instaloader.Instaloader()

posts = instaloader.Profile.from_username(L.context, "keralatourism").get_posts()

SINCE = datetime(2015, 11, 24)
UNTIL = datetime(2017, 3, 20)

for post in takewhile(lambda p: p.date > UNTIL, dropwhile(lambda p: p.date > SINCE, posts)):
    print(post.date)
    L.download_post(post, "keralatourism")
# Out:
# HTTP redirect from https://i.instagram.com/api/v1/users/web_profile_info/?username=keralatourism to https://i.instagram.com/accounts/login/?next=/api/v1/users/web_profile_info/
# ---------------------------------------------------------------------------
# LoginRequiredException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21768\1579653059.py in <module>
#       9 L = instaloader.Instaloader()
#      10
# ---> 11 posts = instaloader.Profile.from_username(L.context, "keralatourism").get_posts()
#      12
#      13 SINCE = datetime(2015, 11, 24)
#
# ~\anaconda3\lib\site-packages\instaloader\structures.py in from_username(cls, context, username)
#     702         # pylint:disable=protected-access
#     703         profile = cls(context, {'username': username.lower()})
# --> 704         profile._obtain_metadata()  # to raise ProfileNotExistsException now in case username is invalid
#     705         return profile
#     706
#
# ...
